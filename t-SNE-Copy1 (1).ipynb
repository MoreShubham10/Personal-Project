# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import fnmatch
import os
import numpy as np
import librosa
import matplotlib.pyplot as plt
import librosa.display
from sklearn.manifold import TSNE
import json

# %%
path = 'F:\Music_Notes'

# %%
files = []
for root, dirnames, filenames in os.walk(path):
    for filename in fnmatch.filter(filenames, '*.wav'):
        files.append(os.path.join(root, filename))

print("found %d .wav files in %s"%(len(files),path))
# Out:
# found 50 .wav files in F:\Music_Notes

# %%
def get_features(y, sr):
    y = y[0:sr]
    S = librosa.feature.melspectrogram(y,sr=sr, n_mels=128)
    log_S = librosa.amplitude_to_db(S, ref=np.max)
    mfcc = librosa.feature.mfcc(S=log_S, n_mfcc=13)
    delta_mfcc = librosa.feature.delta(mfcc, mode='nearest')
    delta2_mfcc = librosa.feature.delta(mfcc, order=2, mode='nearest')
    feature_vector = np.concatenate((np.mean(mfcc,1), np.mean(delta_mfcc,1), np.mean(delta2_mfcc,1)))
    feature_vector = (feature_vector-np.mean(feature_vector)) / np.std(feature_vector)
    return feature_vector

# %%
feature_vectors = []
sound_paths = []
for i,f in enumerate(files):
   # if i % 100 == 0:  this was because there were 6000 sounds in original dataset and printing every single is lengthy
    print("get %d of %d = %s"%(i+1, len(files), f))
    try:
        y, sr = librosa.load(f)
        if len(y) < 2:
            print("error loading %s" % f)
            continue
        feat = get_features(y, sr)
        feature_vectors.append(feat)
        sound_paths.append(f)
    except:
        print("error loading %s" % f)
        
print("calculated %d feature vectors"%len(feature_vectors))
# Out:
# get 1 of 50 = F:\Music_Notes\072_the-mystery-begins-guitar-space.wav
# get 2 of 50 = F:\Music_Notes\074_acoustic-guitar-strummy1.wav
# get 3 of 50 = F:\Music_Notes\074_acoustic-guitar-strummy2.wav
# get 4 of 50 = F:\Music_Notes\075_coal-mine-guitar-part.wav
# get 5 of 50 = F:\Music_Notes\079_bright-leady-guitar.wav
# get 6 of 50 = F:\Music_Notes\080_country-boy-slide-guitar.wav
# get 7 of 50 = F:\Music_Notes\080_country-boy-slide-guitar2.wav
# get 8 of 50 = F:\Music_Notes\081_deeply-crunchy-guitar-stutter-funk.wav
# get 9 of 50 = F:\Music_Notes\084_lone-wolf-guitar-strut.wav
# get 10 of 50 = F:\Music_Notes\085_fretless-dulcimer.wav
# get 11 of 50 = F:\Music_Notes\089_backwards-acoustic-guitar-looper.wav
# get 12 of 50 = F:\Music_Notes\090_flangy-guitar-picked-melody.wav
# get 13 of 50 = F:\Music_Notes\090_flangy-guitar-strummed-melody.wav
# get 14 of 50 = F:\Music_Notes\A.wav
# get 15 of 50 = F:\Music_Notes\A_Drum.wav
# get 16 of 50 = F:\Music_Notes\B.wav
# get 17 of 50 = F:\Music_Notes\Bb.wav
# get 18 of 50 = F:\Music_Notes\Bb_Drum.wav
# get 19 of 50 = F:\Music_Notes\B_Drum.wav
# get 20 of 50 = F:\Music_Notes\C.wav
# get 21 of 50 = F:\Music_Notes\C1.wav
# get 22 of 50 = F:\Music_Notes\C1_Drum.wav
# get 23 of 50 = F:\Music_Notes\cello.wav
# get 24 of 50 = F:\Music_Notes\Cq1_Drum.wav
# get 25 of 50 = F:\Music_Notes\Cq_Drum.wav
# get 26 of 50 = F:\Music_Notes\C_Drum.wav
# get 27 of 50 = F:\Music_Notes\C_s.wav
# get 28 of 50 = F:\Music_Notes\C_s1.wav
# get 29 of 50 = F:\Music_Notes\D.wav
# get 30 of 50 = F:\Music_Notes\D1.wav
# get 31 of 50 = F:\Music_Notes\D1_Drum.wav
# get 32 of 50 = F:\Music_Notes\Dq1_Drum.wav
# get 33 of 50 = F:\Music_Notes\Dq_Drum.wav
# get 34 of 50 = F:\Music_Notes\D_Drum.wav
# get 35 of 50 = F:\Music_Notes\D_s.wav
# get 36 of 50 = F:\Music_Notes\D_s1.wav
# get 37 of 50 = F:\Music_Notes\E.wav
# get 38 of 50 = F:\Music_Notes\E1.wav
# get 39 of 50 = F:\Music_Notes\E1_Drum.wav
# get 40 of 50 = F:\Music_Notes\E_Drum.wav
# get 41 of 50 = F:\Music_Notes\F.wav
# get 42 of 50 = F:\Music_Notes\F1.wav
# get 43 of 50 = F:\Music_Notes\F1_Drum.wav
# get 44 of 50 = F:\Music_Notes\Fq_Drum.wav
# get 45 of 50 = F:\Music_Notes\F_Drum.wav
# get 46 of 50 = F:\Music_Notes\F_s.wav
# get 47 of 50 = F:\Music_Notes\G.wav
# get 48 of 50 = F:\Music_Notes\Gq_Drum.wav
# get 49 of 50 = F:\Music_Notes\G_Drum.wav
# get 50 of 50 = F:\Music_Notes\G_s.wav
# calculated 50 feature vectors

# %%
model = TSNE(n_components=2, learning_rate=150, perplexity=2, verbose=2, angle=0.1).fit_transform(feature_vectors)
# Out:
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 50 samples in 0.001s...
# [t-SNE] Computed neighbors for 50 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 50 / 50
# [t-SNE] Mean sigma: 0.051435
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 70.2769241, gradient norm = 0.6259154 (50 iterations in 0.025s)
# [t-SNE] Iteration 100: error = 72.5689011, gradient norm = 0.4252386 (50 iterations in 0.019s)
# [t-SNE] Iteration 150: error = 75.1026611, gradient norm = 0.5582736 (50 iterations in 0.028s)
# [t-SNE] Iteration 200: error = 67.9877930, gradient norm = 0.5221327 (50 iterations in 0.029s)
# [t-SNE] Iteration 250: error = 64.7421417, gradient norm = 0.3461628 (50 iterations in 0.011s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 64.742142
# [t-SNE] Iteration 300: error = 1.7188928, gradient norm = 0.0077017 (50 iterations in 0.013s)
# [t-SNE] Iteration 350: error = 1.6482733, gradient norm = 0.0031976 (50 iterations in 0.030s)
# [t-SNE] Iteration 400: error = 1.5495243, gradient norm = 0.0009308 (50 iterations in 0.019s)
# [t-SNE] Iteration 450: error = 1.3886102, gradient norm = 0.0008138 (50 iterations in 0.036s)
# [t-SNE] Iteration 500: error = 1.3050239, gradient norm = 0.0004874 (50 iterations in 0.024s)
# [t-SNE] Iteration 550: error = 1.1828849, gradient norm = 0.0014609 (50 iterations in 0.027s)
# [t-SNE] Iteration 600: error = 1.1403288, gradient norm = 0.0006777 (50 iterations in 0.025s)
# [t-SNE] Iteration 650: error = 0.9492971, gradient norm = 0.0011106 (50 iterations in 0.024s)
# [t-SNE] Iteration 700: error = 0.9164675, gradient norm = 0.0002185 (50 iterations in 0.016s)
# [t-SNE] Iteration 750: error = 0.8737168, gradient norm = 0.0002249 (50 iterations in 0.031s)
# [t-SNE] Iteration 800: error = 0.7757999, gradient norm = 0.0007284 (50 iterations in 0.017s)
# [t-SNE] Iteration 850: error = 0.6793378, gradient norm = 0.0002264 (50 iterations in 0.031s)
# [t-SNE] Iteration 900: error = 0.6490606, gradient norm = 0.0001619 (50 iterations in 0.018s)
# [t-SNE] Iteration 950: error = 0.5721772, gradient norm = 0.0004833 (50 iterations in 0.018s)
# [t-SNE] Iteration 1000: error = 0.4208347, gradient norm = 0.0006505 (50 iterations in 0.070s)
# [t-SNE] KL divergence after 1000 iterations: 0.420835

# %%
print(files[0])
# Out:
# F:\Music_Notes\072_the-mystery-begins-guitar-space.wav

# %%
n = len(feature_vectors)
names = [None]*n
i = 0
for note in files:
    spl = note.split("\\")
    x = spl[2].split(".")
    names[i] = x[0]
    i+=1
print(names)
# Out:
# ['072_the-mystery-begins-guitar-space', '074_acoustic-guitar-strummy1', '074_acoustic-guitar-strummy2', '075_coal-mine-guitar-part', '079_bright-leady-guitar', '080_country-boy-slide-guitar', '080_country-boy-slide-guitar2', '081_deeply-crunchy-guitar-stutter-funk', '084_lone-wolf-guitar-strut', '085_fretless-dulcimer', '089_backwards-acoustic-guitar-looper', '090_flangy-guitar-picked-melody', '090_flangy-guitar-strummed-melody', 'A', 'A_Drum', 'B', 'Bb', 'Bb_Drum', 'B_Drum', 'C', 'C1', 'C1_Drum', 'cello', 'Cq1_Drum', 'Cq_Drum', 'C_Drum', 'C_s', 'C_s1', 'D', 'D1', 'D1_Drum', 'Dq1_Drum', 'Dq_Drum', 'D_Drum', 'D_s', 'D_s1', 'E', 'E1', 'E1_Drum', 'E_Drum', 'F', 'F1', 'F1_Drum', 'Fq_Drum', 'F_Drum', 'F_s', 'G', 'Gq_Drum', 'G_Drum', 'G_s']

# %%
x_axis=model[:,0]
y_axis=model[:,1]
plt.figure(figsize = (10,10))
plt.scatter(x_axis, y_axis)
for i, txt in enumerate(names):
    plt.annotate(txt, (x_axis[i], y_axis[i]))
plt.show()

# %%
print(len(x_axis))
print(x_axis)
# Out:
# 50
# [ 169.61101     -4.728958   -16.559906   111.448044   106.266335
#    98.98275     60.269524   -56.310226    32.38336     42.59957
#   180.01582     13.074706   158.62868   -256.4098     -47.72548
#    93.3628      79.24691   -195.55205   -191.14207     69.79394
#   115.38415   -179.72975     73.93391   -171.62259     91.91977
#   101.36435     76.00525    131.76134     83.28725    158.66956
#  -161.51883   -146.5089      63.343777    78.670555  -135.62233
#   174.25162   -125.885025   216.0963    -124.54411     43.12556
#  -116.30161    229.31795   -114.03234      4.0082316   20.623323
#  -208.37218   -227.80533    -37.794308   -25.775866  -241.63594  ]

# %%
from matplotlib.widgets import Button

# %%
import winsound
import matplotlib.pyplot as plt
# %matplotlib nbagg
import numpy as np; np.random.seed(1)
import mpld3
x = x_axis
y = y_axis

names = np.array(names)
c = np.random.randint(1,5,size=50)

norm = plt.Normalize(1,4)
cmap = plt.cm.RdYlGn

fig,ax = plt.subplots()
sc = plt.scatter(x,y,c=c,s=30, cmap=cmap, norm=norm)
ax.set_facecolor("black")

annot = ax.annotate("", xy=(0,0), xytext=(20,20),textcoords="offset points",
                    bbox=dict(boxstyle="round", fc="w"),
                    arrowprops=dict(arrowstyle="->"))
annot.set_visible(False)

def update_annot(ind):

    pos = sc.get_offsets()[ind["ind"][0]]
    annot.xy = pos
    text = "{}, {}".format(" ".join(list(map(str,ind["ind"]))), 
                           " ".join([names[n] for n in ind["ind"]]))
    annot.set_text(text)
    annot.get_bbox_patch().set_facecolor(cmap(norm(c[ind["ind"][0]])))
    annot.get_bbox_patch().set_alpha(0.4)
    
def hover(event):
    vis = annot.get_visible()
    if event.inaxes == ax:
        cont, ind = sc.contains(event)
        if cont:
            update_annot(ind)
            annot.set_visible(True)
            winsound.PlaySound(sound_paths[ind["ind"][0]], winsound.SND_ASYNC | winsound.SND_ALIAS )
            fig.canvas.draw_idle()
        else:
            if vis:
                annot.set_visible(False)
                winsound.PlaySound(None, winsound.SND_ASYNC)
                fig.canvas.draw_idle()



fig.canvas.mpl_connect("motion_notify_event", hover)

import plotly.graph_objects as go
f = go.FigureWidget([go.Scatter(x=x, y=y, mode='markers')])
scatter = f.data[0]
colors = ['#a3a7e4'] * 100
scatter.marker.color = colors
scatter.marker.size = [10] * 100
f.layout.hovermode = 'closest'


# create our callback function
def update_point(trace, points, selector):
    print("hell yes")
    c = list(scatter.marker.color)
    s = list(scatter.marker.size)
    for i in points.point_inds:
        c[i] = '#bae2be'
        s[i] = 20
        with f.batch_update():
            scatter.marker.color = c
            scatter.marker.size = s


scatter.on_click(update_point)

plt.show()


#plot sth
plt.savefig('E:/test.png')

html = 'Some html head' + '<img src=\'E:/test.png\'>' + 'Some more html'

with open('E:/x.html','w') as f:
    f.write(html)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
winsound.PlaySound(files[0], winsound.SND_ASYNC | winsound.SND_ALIAS )

# %%
print(files)
# Out:
# ['F:\\Music_Notes\\072_the-mystery-begins-guitar-space.wav', 'F:\\Music_Notes\\074_acoustic-guitar-strummy1.wav', 'F:\\Music_Notes\\074_acoustic-guitar-strummy2.wav', 'F:\\Music_Notes\\075_coal-mine-guitar-part.wav', 'F:\\Music_Notes\\079_bright-leady-guitar.wav', 'F:\\Music_Notes\\080_country-boy-slide-guitar.wav', 'F:\\Music_Notes\\080_country-boy-slide-guitar2.wav', 'F:\\Music_Notes\\081_deeply-crunchy-guitar-stutter-funk.wav', 'F:\\Music_Notes\\084_lone-wolf-guitar-strut.wav', 'F:\\Music_Notes\\085_fretless-dulcimer.wav', 'F:\\Music_Notes\\089_backwards-acoustic-guitar-looper.wav', 'F:\\Music_Notes\\090_flangy-guitar-picked-melody.wav', 'F:\\Music_Notes\\090_flangy-guitar-strummed-melody.wav', 'F:\\Music_Notes\\A.wav', 'F:\\Music_Notes\\A_Drum.wav', 'F:\\Music_Notes\\B.wav', 'F:\\Music_Notes\\Bb.wav', 'F:\\Music_Notes\\Bb_Drum.wav', 'F:\\Music_Notes\\B_Drum.wav', 'F:\\Music_Notes\\C.wav', 'F:\\Music_Notes\\C1.wav', 'F:\\Music_Notes\\C1_Drum.wav', 'F:\\Music_Notes\\cello.wav', 'F:\\Music_Notes\\Cq1_Drum.wav', 'F:\\Music_Notes\\Cq_Drum.wav', 'F:\\Music_Notes\\C_Drum.wav', 'F:\\Music_Notes\\C_s.wav', 'F:\\Music_Notes\\C_s1.wav', 'F:\\Music_Notes\\D.wav', 'F:\\Music_Notes\\D1.wav', 'F:\\Music_Notes\\D1_Drum.wav', 'F:\\Music_Notes\\Dq1_Drum.wav', 'F:\\Music_Notes\\Dq_Drum.wav', 'F:\\Music_Notes\\D_Drum.wav', 'F:\\Music_Notes\\D_s.wav', 'F:\\Music_Notes\\D_s1.wav', 'F:\\Music_Notes\\E.wav', 'F:\\Music_Notes\\E1.wav', 'F:\\Music_Notes\\E1_Drum.wav', 'F:\\Music_Notes\\E_Drum.wav', 'F:\\Music_Notes\\F.wav', 'F:\\Music_Notes\\F1.wav', 'F:\\Music_Notes\\F1_Drum.wav', 'F:\\Music_Notes\\Fq_Drum.wav', 'F:\\Music_Notes\\F_Drum.wav', 'F:\\Music_Notes\\F_s.wav', 'F:\\Music_Notes\\G.wav', 'F:\\Music_Notes\\Gq_Drum.wav', 'F:\\Music_Notes\\G_Drum.wav', 'F:\\Music_Notes\\G_s.wav']

# %%
def play():
    winsound.PlaySound(files[0], winsound.SND_ASYNC | winsound.SND_ALIAS )

from bokeh.models import ColumnDataSource, OpenURL, TapTool
from bokeh.plotting import figure, output_file, show
from bokeh.models import CustomJSHover

from math import sin
from random import random

from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource, HoverTool, LinearColorMapper
from bokeh.palettes import plasma
from bokeh.plotting import figure
from bokeh.transform import transform

output_file("openurl.html")
#plays = CustomJSHover(return winsound.PlaySound(files[0], winsound.SND_ASYNC | winsound.SND_ALIAS ))

source = ColumnDataSource(data=dict(
    x=x,
    y=y,
    label = names,
    spath = files,
    color=["navy", "orange", "olive", "firebrick", "gold","navy", "orange", "olive", "firebrick", "gold","navy", "orange", "olive", "firebrick", "gold","navy", "orange", "olive", "firebrick", "gold","navy", "orange", "olive", "firebrick", "gold","navy", "orange", "olive", "firebrick", "gold","navy", "orange", "olive", "firebrick", "gold","navy", "orange", "olive", "firebrick", "gold","navy", "orange", "olive", "firebrick", "gold","navy", "orange", "olive", "firebrick", "gold"]
    ))

TOOLTIPS = """                  #for a datapoint information
    <div>
    <h1>MUSIC CREATION DUDE</h1>
        <div>
            <audio controls autoplay>
              <source src= @spath>
            </audio>
        </div>
        <div>
            <span style="font-size: 15px; color: #966;">[$index]</span>
            <span style="font-size: 17px; font-weight: bold;">@label</span>
        </div>
    </div>
"""

hover = HoverTool(tooltips=TOOLTIPS, show_arrow=False)
    
fig = figure(plot_width=1200, plot_height=750,
           tools= [hover], title="Click the Dots")
fig.grid.grid_line_color = None
#toolbar_location=None

fig.circle('x', 'y', color='color', size=10, source=source)

url = "http://www.colors.commutercreative.com/@color/"
taptool = fig.select(type=TapTool)
taptool.callback = OpenURL(url=url)

show(fig)                                    #shows you the visualization
